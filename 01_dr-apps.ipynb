# %%
# !pip install git+https://github.com/datarobot/dr-apps # -qq
# Out:
# ...
#   Cloning https://github.com/datarobot/dr-apps to /tmp/pip-req-build-ql4l8rj1
# done
# done
# done
# ...
#      |████████████████████████████████| 62 kB 10.2 MB/s
# ...
# done
#   Created wheel for drapps: filename=drapps-0.2.3-py3-none-any.whl size=19456 sha256=104f6c100a3513a66f2186d09066f635d7fc48c0c29ab150956fe0bb90ecac71
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btyjybyk/wheels/dc/ed/e4/791a4ddf6aeb3c90f6484ad2b414014b4df60c168c8045943e
# done
#   Created wheel for bson: filename=bson-0.5.10-py3-none-any.whl size=11976 sha256=c46cdd89d6ad52b63be600640940f0b98cb086bb03d8a2d5a08c5d7585ab8920
#   Stored in directory: /tmp/pip-ephem-wheel-cache-btyjybyk/wheels/6d/8b/5e/68619cb02962978c6cc8eaf68ca23ef28c69de7e086740702b
# Successfully built drapps bson
# ...
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# ...

# %%
# !drapps --help
# Out:
# Usage: drapps [OPTIONS] COMMAND [ARGS]...
#
#   CLI tools for custom applications.
#
#   You can use drapps COMMAND --help for getting more info about command.
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   create     Creates new custom application from docker image or base...
#   logs       Provides logs for custom application.
#   ls         Provides list of custom applications or execution environments.
#   terminate  Stops custom application and removes it from the list.

# %%
app_name = "[Demo] QAボット Admin"

# %%
# !drapps create -e "[Experimental] Python 3.9 Streamlit" -p ./qa_streamlit "$app_name"
# Out:
# Using [Demo] QAボット AdminSource custom application source.
# Creating new version for [Demo] QAボット AdminSource custom application source.
# Uploading project:  [####################################]  100%
# Starting [Demo] QAボット Admin custom application.
# Waiting till app is ready:  [-----------------------------------#]
# Custom application is running: https://app.datarobot.com/custom_applications/66600375fd34b7944072b8a1/

# %%
# notebookのキーは一時的なもので、常時利用可能なものではありません
# !drapps ls apps
# Out:
# id                        name                   status    updated    URL
# ------------------------  ---------------------  --------  ---------  -----------------------------------------------------------------------
# 665feb8b841f35059829c244  Q&A Application Admin  running   04:58:01   https://app.datarobot.com/custom_applications/665feb8b841f35059829c244/
# 665ff20a24718b830272ba15  Q&A Application 2      running   05:07:59   https://app.datarobot.com/custom_applications/665ff20a24718b830272ba15/
# 66600375fd34b7944072b8a1  [Demo] QAボット Admin  running   06:26:16   https://app.datarobot.com/custom_applications/66600375fd34b7944072b8a1/

# %%
# !drapps terminate "$app_name"
# Out:
# Custom application [Demo] QAボット was deleted.

# %%
# !drapps create --image "flask_test.tar.gz" "[Test]flask App2" --skip-wait
# Out:
# Uploading flask_test.tar.gz to Data Robot.
# Upload progress:  [####################################]  100%
# Waiting till image is ready:  [------------------------------#-----]
# Starting [Test]flask App2 custom application.
# Custom application [Test]flask App2 was successfully created.

# %%
# !drapps logs "[Test]flask App1"
# Out:
# This app currently has no logs.
