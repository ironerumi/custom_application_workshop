# %%
# !pip install git+https://github.com/datarobot/dr-apps # -qq
# Out:
# ...
#   Cloning https://github.com/datarobot/dr-apps to /tmp/pip-req-build-mbfy59yd
# done
# done
# done
# ...
# done
#   Created wheel for drapps: filename=drapps-0.2.3-py3-none-any.whl size=19456 sha256=3dfa515e2944afb95d6276dd9e5063c46a902b1cebaa52eddb08259edaf57bb3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lhperdzh/wheels/dc/ed/e4/791a4ddf6aeb3c90f6484ad2b414014b4df60c168c8045943e
# done
#   Created wheel for bson: filename=bson-0.5.10-py3-none-any.whl size=11977 sha256=46b41935fc97fc5f3e4587e9ed0de128c17221e5eafd9d8eb6a9f97018b0bb33
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lhperdzh/wheels/6d/8b/5e/68619cb02962978c6cc8eaf68ca23ef28c69de7e086740702b
# Successfully built drapps bson
# ...
# WARNING: You are using pip version 20.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/home/notebooks/storage/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
# !drapps --help
# Out:
# Usage: drapps [OPTIONS] COMMAND [ARGS]...
#
#   CLI tools for custom applications.
#
#   You can use drapps COMMAND --help for getting more info about command.
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   create     Creates new custom application from docker image or base...
#   logs       Provides logs for custom application.
#   ls         Provides list of custom applications or execution environments.
#   terminate  Stops custom application and removes it from the list.

# %%
app_name = "[Demo] QAボット XXX 任意の名前を入れてください XXX"

# %%
# !drapps create -e "[Test] Python 3.9 App" -p ./app_st_single_user "$app_name"
# Out:
# Using [Demo] QAボットImage custom application image.
# Creating new version for [Demo] QAボットImage custom application image.
# Uploading project:  [####################################]  100%
# Starting [Demo] QAボット custom application.
# Waiting till app is ready:  [----------------------#-------------]
# Custom application is running: https://app.datarobot.com/custom_applications/65c1a6bcafbc2044ce02859e/

# %%
# notebookのキーは一時的なもので、常時利用可能なものではありません
# !drapps ls apps
# Out:
# id                        name                status    updated     URL
# ------------------------  ------------------  --------  ----------  -----------------------------------------------------------------------
# 65bc90c7731682df4535217a  [test] chatapp1     running   2024-02-02  https://app.datarobot.com/custom_applications/65bc90c7731682df4535217a/
# 65c016bd023b7a6a74555f7c  [test] chatapp4     running   2024-02-04  https://app.datarobot.com/custom_applications/65c016bd023b7a6a74555f7c/
# 65c09fad73e103ffc835240d  [Test] App          running   2024-02-05  https://app.datarobot.com/custom_applications/65c09fad73e103ffc835240d/
# 65c0d40cf058c362a6351ea7  [Test] App1         running   2024-02-05  https://app.datarobot.com/custom_applications/65c0d40cf058c362a6351ea7/
# 65c0f3c71b7e42f31db25f16  [Test] App2         running   2024-02-05  https://app.datarobot.com/custom_applications/65c0f3c71b7e42f31db25f16/
# ...

# %%
# !drapps terminate "$app_name"
# Out:
# Custom application [Demo] QAボット was deleted.

# %%
# !drapps create --image "flask_test.tar.gz" "[Test]flask App1" --skip-wait
# Out:
# Uploading flask_test.tar.gz to Data Robot.
# Upload progress:  [####################################]  100%
# Waiting till image is ready:  [------------------------------#-----]
# Starting [Test]flask App1 custom application.
# Custom application [Test]flask App1 was successfully created.

# %%
# !drapps logs "[Test]flask App1"
# Out:
# This app currently has no logs.
