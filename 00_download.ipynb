# %%
# !wget https://github.com/ironerumi/custom_application_workshop/archive/refs/heads/main.zip -O apps.zip
# !unzip apps.zip
# !rm apps.zip
# Out:
# --2024-06-04 23:43:03--  https://github.com/ironerumi/custom_application_workshop/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ironerumi/custom_application_workshop/zip/refs/heads/main [following]
# --2024-06-04 23:43:03--  https://codeload.github.com/ironerumi/custom_application_workshop/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘apps.zip’
#
# apps.zip                [    <=>             ]  51.93M  22.3MB/s    in 2.3s
#
# 2024-06-04 23:43:05 (22.3 MB/s) - ‘apps.zip’ saved [54448475]
#
# Archive:  apps.zip
# 3a9c813a88ce95c1b0d4747cc40a8f166b34fbb2
# ...
